# %%
import matplotlib.pyplot as plt
import numpy as np
import GPy
import pandas as pd

from gpr4im import fg_tools as fg
from gpr4im import pk_tools as pk

# %%
# for plotting:
# %matplotlib inline

font = {"size": 16, "family": "STIXGeneral"}
axislabelfontsize = "x-large"
plt.rc("font", **font)
plt.rcParams["text.usetex"] = True

# %% [markdown]
# ## Low frequency range
#
# Loading data, and cutting bandwidth in half.

# %%
data = pd.read_pickle('../../Data/data.pkl')
multinest_results = pd.read_pickle('../../Data/multinest_results.pkl')
# cutting in the low frequency range:
FGwpol_HI_noise_data = data.beam.FGwpol_HI_noise[:, :, :143]
HI_noise_data = data.beam.HI_noise[:, :, :143]
freqs = data.freqs[:143]
multinest = multinest_results.wpol_lofreq

# %% [markdown]
# PCA foreground removal:

# %%
pca_res4 = fg.PCAclean(FGwpol_HI_noise_data, N_FG=4)[0]
pca_res5 = fg.PCAclean(FGwpol_HI_noise_data, N_FG=5)[0]

# %%
kern_smooth = GPy.kern.RBF(1, variance = multinest.rbf1_var, lengthscale = multinest.rbf1_len)
kern_pol = GPy.kern.RBF(1, variance = multinest.rbf2_var, lengthscale = multinest.rbf2_len)
kern_fg = kern_smooth + kern_pol
kern_21 = GPy.kern.Exponential(1, variance = multinest.exp_var, lengthscale = multinest.exp_len)

Input = FGwpol_HI_noise_data

gpr_result = fg.GPRclean(Input, freqs, kern_fg, kern_21, num_restarts=0, NprePCA=0, 
                                        noise_data=None, heteroscedastic=False, zero_noise=True, invert=False)
# Out:
#  /opt/anaconda3/envs/testgpr2/lib/python3.7/site-packages/paramz/transformations.py:111: RuntimeWarning:overflow encountered in expm1
#  /opt/anaconda3/envs/testgpr2/lib/python3.7/site-packages/paramz/transformations.py:111: RuntimeWarning:divide by zero encountered in log

# %%
gpr_result.model
# Out:
# <style type="text/css">
# .pd{
#     font-family: "Courier New", Courier, monospace !important;
#     width: 100%;
#     padding: 3px;
# }
# </style>
#
# <p class=pd>
# <b>Model</b>: GP regression<br>
# <b>Objective</b>: -22647276.869787417<br>
# <b>Number of Parameters</b>: 7<br>
# <b>Number of Optimization Parameters</b>: 6<br>
# <b>Updates</b>: True<br>
# </p>
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg th{font-family:"Courier New", Courier, monospace !important;font-weight:normal;color:#fff;background-color:#26ADE4;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg .tg-left{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:left;}
# .tg .tg-center{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:center;}
# .tg .tg-right{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:right;}
# </style>
# <table class="tg"><tr><th><b>  GP_regression.             </b></th><th><b>               value</b></th><th><b>constraints</b></th><th><b>priors</b></th></tr>
# <tr><td class=tg-left>  sum.rbf.variance           </td><td class=tg-right>   57505.27335619189</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.rbf.lengthscale        </td><td class=tg-right>   489.6148983876146</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.rbf_1.variance         </td><td class=tg-right>   5.368353260260953</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.rbf_1.lengthscale      </td><td class=tg-right>   74.52394664469603</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.Exponential.variance   </td><td class=tg-right>0.001434041875029721</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.Exponential.lengthscale</td><td class=tg-right>    8.01553747735935</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  Gaussian_noise.variance    </td><td class=tg-right>                 0.0</td><td class=tg-center> +ve fixed </td><td class=tg-center>      </td></tr>
# </table>

# %% [markdown]
# Calculate power spectrum:

# %%
# Dimension of data cube:
lx, ly, lz = 1000,1000, 924.78*(143/285) #Mpc/h
nx, ny, nz = 256, 256, 143
# weighting and window function:
w = W = np.ones((nx,ny,nz))

# minimum and maximum k in each direction:
kmin, kmin_perp, kmin_par = 2*np.pi/pow(lx*ly*lz, 1/3), 2*np.pi/np.sqrt(lx**2 + ly**2), 2*np.pi/lz
kmax, kmax_par, kmax_perp = 0.4, 0.4, 0.4

# set width of k bins to be 2*kmin
dk, dk_perp, dk_par = 2*kmin, 2*kmin_perp, 2*kmin_par

# number of k bins:
nkbin = int((kmax-kmin)/dk)
nkbin_perp = int((kmax_perp-kmin_perp)/dk_perp)
nkbin_par = int((kmax_par-kmin_par)/dk_par)

# setting array of k bin edges:
kbins = np.arange(kmin,kmax,dk)
kbins_perp = np.arange(kmin_perp,kmax_perp,dk_perp)
kbins_par = np.arange(kmin_par,kmax_par,dk_par)

# array of kbin centers:
k = np.linspace(kmin+0.5*dk,kmax-0.5*dk,nkbin)
kperp = np.linspace(kmin_perp+0.5*dk_perp,kmax_perp-0.5*dk_perp,nkbin_perp)
kpar = np.linspace(kmin_par+0.5*dk_par,kmax_par-0.5*dk_par,nkbin_par)

# %%
# spherically averaged power spectrum:

# true HI power spectrum:
HI_pk = pk.getpk(HI_noise_data,w,W,nx,ny,nz,lx,ly,lz,kbins)[0]
# residual power spectrum from GPR:
GPR_pk = pk.getpk(gpr_result.res,w,W,nx,ny,nz,lx,ly,lz,kbins)[0]
# residual power spectrum from PCA:
PCA5_pk = pk.getpk(pca_res5,w,W,nx,ny,nz,lx,ly,lz,kbins)[0]
PCA4_pk = pk.getpk(pca_res4,w,W,nx,ny,nz,lx,ly,lz,kbins)[0]

# radial power spectrum:

# true HI power spectrum:
HI_pk_para = pk.ParaPk(HI_noise_data, nx, ny, nz, lx, ly, lz, kbins_par, w, W)[0]
# residual power spectrum from GPR:
GPR_pk_para = pk.ParaPk(gpr_result.res, nx, ny, nz, lx, ly, lz, kbins_par, w, W)[0]
# residual power spectrum from PCA:
PCA5_pk_para = pk.ParaPk(pca_res5, nx, ny, nz, lx, ly, lz, kbins_par, w, W)[0]
PCA4_pk_para = pk.ParaPk(pca_res4, nx, ny, nz, lx, ly, lz, kbins_par, w, W)[0]

# transverse power spectrum:

# true HI power spectrum:
HI_pk_perp = pk.PerpPk(HI_noise_data, nx, ny, nz, lx, ly, lz, kbins_perp, w, W)[0]
# residual power spectrum from GPR, with bias correction:
GPR_pk_perp = pk.PerpPk(gpr_result.res, nx, ny, nz, lx, ly, lz, kbins_perp, w, W)[0]
# residual power spectrum from PCA:
PCA5_pk_perp = pk.PerpPk(pca_res5, nx, ny, nz, lx, ly, lz, kbins_perp, w, W)[0]
PCA4_pk_perp = pk.PerpPk(pca_res4, nx, ny, nz, lx, ly, lz, kbins_perp, w, W)[0]

# %%
fig, ((ax1, ax3, ax5), (ax2, ax4, ax6)) = plt.subplots(nrows=2, ncols=3, sharex='col', figsize=(21,9), gridspec_kw={'height_ratios': [3, 1.7]})
fig.subplots_adjust(hspace=0, wspace=0.24)

ax1.plot(k, (k*k*k*HI_pk)/(2*np.pi*np.pi), ls='solid', c='k', lw=6, label = r'HI + noise data')
ax1.plot(k, (k*k*k*PCA5_pk)/(2*np.pi*np.pi), ls='dotted',c='b', lw=4)
ax1.plot(k, (k*k*k*PCA4_pk)/(2*np.pi*np.pi), ls='dashdot',c='r', lw=4)
ax1.plot(k, (k*k*k*GPR_pk)/(2*np.pi*np.pi), ls='dashed', c='limegreen', lw=5)
ax1.text(k[0]*5.3, 0.000095, r'$k = 0.08 \, h$/Mpc', c='hotpink')
ax1.axvline(k[4], c='hotpink')
ax1.set_xscale('log')
ax1.set_ylim(0,0.0005)
ax1.set_ylabel('$\Delta^2 (k)$ [mK$^2$]', fontsize=20)

ax2.scatter(k, 100*(PCA5_pk - HI_pk)/HI_pk, marker='s', s=60, edgecolor='b', facecolor='none', lw=2, label = r'PCA clean $N_{\rm FG} = 5$')
ax2.scatter(k, 100*(PCA4_pk - HI_pk)/HI_pk, marker='v', s=90, edgecolor='r', facecolor='none', lw=2, label = r'PCA clean $N_{\rm FG} = 4$')
ax2.scatter(k, 100*(GPR_pk - HI_pk)/HI_pk, s=90, marker='o', edgecolor='limegreen', facecolor='none', lw=2, label = r'GPR clean')
ax2.set_ylim(-10,10)
ax2.axvline(k[4], c='hotpink')
ax2.set_xscale('log')
ax2.set_xlabel('$k$ [$h$/Mpc]', fontsize=20)
ax2.set_ylabel('\% residual', fontsize=20)
ax2.axhline(0, c='k', lw=3)

ax3.plot(kpar, kpar*HI_pk_para, ls='solid', c='k', lw=6)
ax3.plot(kpar, kpar*PCA5_pk_para, ls='dotted',c='b', lw=4, label = r'PCA clean $N_{\rm FG} = 5$')
ax3.plot(kpar, kpar*PCA4_pk_para, ls='dashdot',c='r', lw=4)
ax3.plot(kpar, kpar*GPR_pk_para, ls='dashed', c='limegreen', lw=5)
ax3.text(k[0]*3.6, 0.0027, r'$k_\parallel = 0.06 \, h$/Mpc', c='hotpink')
ax3.axvline(kpar[1], c='hotpink')
ax3.set_xscale('log')
ax3.set_ylabel('$k_\parallel P(k_\parallel)$ [mK$^2$]', fontsize=20)

ax4.scatter(kpar, 100*(PCA5_pk_para - HI_pk_para)/HI_pk_para, marker='s', s=60, edgecolor='b', facecolor='none', lw=2)
ax4.scatter(kpar, 100*(PCA4_pk_para - HI_pk_para)/HI_pk_para, marker='v', s=90, edgecolor='r', facecolor='none', lw=2)
ax4.scatter(kpar, 100*(GPR_pk_para - HI_pk_para)/HI_pk_para, s=90, marker='o', edgecolor='limegreen', facecolor='none', lw=2)
ax4.axvline(kpar[1], c='hotpink')
ax4.set_ylim(-10,5)
ax4.set_xscale('log')
ax4.set_xlabel('$k_\parallel$ [$h$/Mpc]', fontsize=20)
ax4.set_ylabel('\% residual', fontsize=20)
ax4.axhline(0, c='k', lw=3)

ax5.plot(kperp, kperp*kperp*HI_pk_perp, ls='solid', c='k', lw=6)
ax5.plot(kperp, kperp*kperp*PCA5_pk_perp, ls='dotted',c='b', lw=4)
ax5.plot(kperp, kperp*kperp*PCA4_pk_perp, ls='dashdot',c='r', lw=4, label = r'PCA clean $N_{\rm FG} = 4$')
ax5.plot(kperp, kperp*kperp*GPR_pk_perp, ls='dashed', c='limegreen', lw=5, label = r'GPR clean')
ax5.set_xscale('log')
ax5.set_ylabel('$k_\perp^2 P(k_\perp)$ [mK$^2$]', fontsize=20)

ax6.scatter(kperp, 100*(PCA5_pk_perp - HI_pk_perp)/HI_pk_perp, marker='s', s=60, edgecolor='b', facecolor='none', lw=2)
ax6.scatter(kperp, 100*(PCA4_pk_perp - HI_pk_perp)/HI_pk_perp, marker='v', s=90, edgecolor='r', facecolor='none', lw=2)
ax6.scatter(kperp, 100*(GPR_pk_perp - HI_pk_perp)/HI_pk_perp, s=90, marker='o', edgecolor='limegreen', facecolor='none', lw=2)
ax6.set_ylim(-10,10)
ax6.set_xlabel('$k_\perp$ [$h$/Mpc]', fontsize=20)
ax6.set_ylabel('\% residual', fontsize=20)
ax6.axhline(0, c='k', lw=3)

fig.legend(bbox_to_anchor=(0.11, 0.88, 0.8, 0), loc="lower left", mode="expand", ncol=4, fontsize=20)

#plt.savefig('figs/pk_all_wpol_lofreq', dpi=300, bbox_inches="tight")

# %% [markdown]
# ## High frequency range
#
# Here we do the exact same thing but now for the high frequency range

# %%
FGwpol_HI_noise_data = data.beam.FGwpol_HI_noise[:, :, 143:]
HI_noise_data = data.beam.HI_noise[:, :, 143:]
freqs = data.freqs[143:]
multinest = multinest_results.wpol_hifreq

# %%
pca_res4 = fg.PCAclean(FGwpol_HI_noise_data, N_FG=4)[0]
pca_res3 = fg.PCAclean(FGwpol_HI_noise_data, N_FG=3)[0]

# %%
kern_smooth = GPy.kern.RBF(1, variance = multinest.rbf1_var, lengthscale = multinest.rbf1_len)
kern_pol = GPy.kern.RBF(1, variance = multinest.rbf2_var, lengthscale = multinest.rbf2_len)
kern_fg = kern_smooth + kern_pol
kern_21 = GPy.kern.Exponential(1, variance = multinest.exp_var, lengthscale = multinest.exp_len)

Input = FGwpol_HI_noise_data

gpr_result = fg.GPRclean(Input, freqs, kern_fg, kern_21, num_restarts=0, NprePCA=0, 
                                        noise_data=None, heteroscedastic=False, zero_noise=True, invert=False)
# Out:
#  /opt/anaconda3/envs/testgpr2/lib/python3.7/site-packages/paramz/transformations.py:111: RuntimeWarning:overflow encountered in expm1
#  /opt/anaconda3/envs/testgpr2/lib/python3.7/site-packages/paramz/transformations.py:111: RuntimeWarning:divide by zero encountered in log

# %%
gpr_result.model
# Out:
# <style type="text/css">
# .pd{
#     font-family: "Courier New", Courier, monospace !important;
#     width: 100%;
#     padding: 3px;
# }
# </style>
#
# <p class=pd>
# <b>Model</b>: GP regression<br>
# <b>Objective</b>: -22797749.429951116<br>
# <b>Number of Parameters</b>: 7<br>
# <b>Number of Optimization Parameters</b>: 6<br>
# <b>Updates</b>: True<br>
# </p>
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg th{font-family:"Courier New", Courier, monospace !important;font-weight:normal;color:#fff;background-color:#26ADE4;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg .tg-left{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:left;}
# .tg .tg-center{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:center;}
# .tg .tg-right{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:right;}
# </style>
# <table class="tg"><tr><th><b>  GP_regression.             </b></th><th><b>                value</b></th><th><b>constraints</b></th><th><b>priors</b></th></tr>
# <tr><td class=tg-left>  sum.rbf.variance           </td><td class=tg-right>   27100.161877710034</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.rbf.lengthscale        </td><td class=tg-right>    588.6059567105364</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.rbf_1.variance         </td><td class=tg-right>    4.057359254480211</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.rbf_1.lengthscale      </td><td class=tg-right>   106.97714921463871</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.Exponential.variance   </td><td class=tg-right>0.0011284317859334247</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.Exponential.lengthscale</td><td class=tg-right>    6.220363145411224</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  Gaussian_noise.variance    </td><td class=tg-right>                  0.0</td><td class=tg-center> +ve fixed </td><td class=tg-center>      </td></tr>
# </table>

# %%
# Dimension of data cube:
lx, ly, lz = 1000,1000, 924.78*(142/285) #Mpc/h
nx, ny, nz = 256, 256, 142
# weighting and window function:
w = W = np.ones((nx,ny,nz))

# minimum and maximum k in each direction:
kmin, kmin_perp, kmin_par = 2*np.pi/pow(lx*ly*lz, 1/3), 2*np.pi/np.sqrt(lx**2 + ly**2), 2*np.pi/lz
kmax, kmax_par, kmax_perp = 0.4, 0.4, 0.4

# set width of k bins to be 2*kmin
dk, dk_perp, dk_par = 2*kmin, 2*kmin_perp, 2*kmin_par

# number of k bins:
nkbin = int((kmax-kmin)/dk)
nkbin_perp = int((kmax_perp-kmin_perp)/dk_perp)
nkbin_par = int((kmax_par-kmin_par)/dk_par)

# setting array of k bin edges:
kbins = np.arange(kmin,kmax,dk)
kbins_perp = np.arange(kmin_perp,kmax_perp,dk_perp)
kbins_par = np.arange(kmin_par,kmax_par,dk_par)

# array of kbin centers:
k = np.linspace(kmin+0.5*dk,kmax-0.5*dk,nkbin)
kperp = np.linspace(kmin_perp+0.5*dk_perp,kmax_perp-0.5*dk_perp,nkbin_perp)
kpar = np.linspace(kmin_par+0.5*dk_par,kmax_par-0.5*dk_par,nkbin_par)

# %%
# spherically averaged power spectrum:

# true HI power spectrum:
HI_pk = pk.getpk(HI_noise_data,w,W,nx,ny,nz,lx,ly,lz,kbins)[0]
# residual power spectrum from GPR:
GPR_pk = pk.getpk(gpr_result.res,w,W,nx,ny,nz,lx,ly,lz,kbins)[0]
# residual power spectrum from PCA:
PCA4_pk = pk.getpk(pca_res4,w,W,nx,ny,nz,lx,ly,lz,kbins)[0]
PCA3_pk = pk.getpk(pca_res3,w,W,nx,ny,nz,lx,ly,lz,kbins)[0]

# radial power spectrum:

# true HI power spectrum:
HI_pk_para = pk.ParaPk(HI_noise_data, nx, ny, nz, lx, ly, lz, kbins_par, w, W)[0]
# residual power spectrum from GPR:
GPR_pk_para = pk.ParaPk(gpr_result.res, nx, ny, nz, lx, ly, lz, kbins_par, w, W)[0]
# residual power spectrum from PCA:
PCA4_pk_para = pk.ParaPk(pca_res4, nx, ny, nz, lx, ly, lz, kbins_par, w, W)[0]
PCA3_pk_para = pk.ParaPk(pca_res3, nx, ny, nz, lx, ly, lz, kbins_par, w, W)[0]

# transverse power spectrum:

# true HI power spectrum:
HI_pk_perp = pk.PerpPk(HI_noise_data, nx, ny, nz, lx, ly, lz, kbins_perp, w, W)[0]
# residual power spectrum from GPR, with bias correction:
GPR_pk_perp = pk.PerpPk(gpr_result.res, nx, ny, nz, lx, ly, lz, kbins_perp, w, W)[0]
# residual power spectrum from PCA:
PCA4_pk_perp = pk.PerpPk(pca_res4, nx, ny, nz, lx, ly, lz, kbins_perp, w, W)[0]
PCA3_pk_perp = pk.PerpPk(pca_res3, nx, ny, nz, lx, ly, lz, kbins_perp, w, W)[0]

# %%
fig, ((ax1, ax3, ax5), (ax2, ax4, ax6)) = plt.subplots(nrows=2, ncols=3, sharex='col', figsize=(21,9), gridspec_kw={'height_ratios': [3, 1.7]})
fig.subplots_adjust(hspace=0, wspace=0.24)

ax1.plot(k, (k*k*k*HI_pk)/(2*np.pi*np.pi), ls='solid', c='k', lw=6, label = r'HI + noise data')
ax1.plot(k, (k*k*k*PCA4_pk)/(2*np.pi*np.pi), ls='dotted',c='b', lw=4)
ax1.plot(k, (k*k*k*PCA3_pk)/(2*np.pi*np.pi), ls='dashdot',c='r', lw=4)
ax1.plot(k, (k*k*k*GPR_pk)/(2*np.pi*np.pi), ls='dashed', c='limegreen', lw=5)
ax1.text(k[0]*6.3, 0.000095, r'$k = 0.10 \, h$/Mpc', c='hotpink')
ax1.axvline(k[5], c='hotpink')
ax1.set_xscale('log')
ax1.set_ylim(0,0.0005)
ax1.set_ylabel('$\Delta^2 (k)$ [mK$^2$]', fontsize=20)

ax2.scatter(k, 100*(PCA4_pk - HI_pk)/HI_pk, marker='s', s=60, edgecolor='b', facecolor='none', lw=2, label = r'PCA clean $N_{\rm FG} = 4$')
ax2.scatter(k, 100*(PCA3_pk - HI_pk)/HI_pk, marker='v', s=90, edgecolor='r', facecolor='none', lw=2, label = r'PCA clean $N_{\rm FG} = 3$')
ax2.scatter(k, 100*(GPR_pk - HI_pk)/HI_pk, s=90, marker='o', edgecolor='limegreen', facecolor='none', lw=2, label = r'GPR clean')
ax2.set_ylim(-10,2)
ax2.axvline(k[5], c='hotpink')
ax2.set_xscale('log')
ax2.set_xlabel('$k$ [$h$/Mpc]', fontsize=20)
ax2.set_ylabel('\% residual', fontsize=20)
ax2.axhline(0, c='k', lw=3)

ax3.plot(kpar, kpar*HI_pk_para, ls='solid', c='k', lw=6)
ax3.plot(kpar, kpar*PCA4_pk_para, ls='dotted',c='b', lw=4, label = r'PCA clean $N_{\rm FG} = 4$')
ax3.plot(kpar, kpar*PCA3_pk_para, ls='dashdot',c='r', lw=4)
ax3.plot(kpar, kpar*GPR_pk_para, ls='dashed', c='limegreen', lw=5)
ax3.text(k[0]*3.56, 0.0046, r'$k_\parallel = 0.06 \, h$/Mpc', c='hotpink')
ax3.axvline(kpar[1], c='hotpink')
ax3.set_xscale('log')
ax3.set_ylabel('$k_\parallel P(k_\parallel)$ [mK$^2$]', fontsize=20)

ax4.scatter(kpar, 100*(PCA4_pk_para - HI_pk_para)/HI_pk_para, marker='s', s=60, edgecolor='b', facecolor='none', lw=2)
ax4.scatter(kpar, 100*(PCA3_pk_para - HI_pk_para)/HI_pk_para, marker='v', s=90, edgecolor='r', facecolor='none', lw=2)
ax4.scatter(kpar, 100*(GPR_pk_para - HI_pk_para)/HI_pk_para, s=90, marker='o', edgecolor='limegreen', facecolor='none', lw=2)
ax4.axvline(kpar[1], c='hotpink')
ax4.set_ylim(-10,2)
ax4.set_xscale('log')
ax4.set_xlabel('$k_\parallel$ [$h$/Mpc]', fontsize=20)
ax4.set_ylabel('\% residual', fontsize=20)
ax4.axhline(0, c='k', lw=3)

ax5.plot(kperp, kperp*kperp*HI_pk_perp, ls='solid', c='k', lw=6)
ax5.plot(kperp, kperp*kperp*PCA4_pk_perp, ls='dotted',c='b', lw=4)
ax5.plot(kperp, kperp*kperp*PCA3_pk_perp, ls='dashdot',c='r', lw=4, label = r'PCA clean $N_{\rm FG} = 3$')
ax5.plot(kperp, kperp*kperp*GPR_pk_perp, ls='dashed', c='limegreen', lw=5, label = r'GPR clean')
ax5.set_xscale('log')
ax5.set_ylabel('$k_\perp^2 P(k_\perp)$ [mK$^2$]', fontsize=20)

ax6.scatter(kperp, 100*(PCA4_pk_perp - HI_pk_perp)/HI_pk_perp, marker='s', s=60, edgecolor='b', facecolor='none', lw=2)
ax6.scatter(kperp, 100*(PCA3_pk_perp - HI_pk_perp)/HI_pk_perp, marker='v', s=90, edgecolor='r', facecolor='none', lw=2)
ax6.scatter(kperp, 100*(GPR_pk_perp - HI_pk_perp)/HI_pk_perp, s=90, marker='o', edgecolor='limegreen', facecolor='none', lw=2)
ax6.set_ylim(-10,2)
ax6.set_xlabel('$k_\perp$ [$h$/Mpc]', fontsize=20)
ax6.set_ylabel('\% residual', fontsize=20)
ax6.axhline(0, c='k', lw=3)

fig.legend(bbox_to_anchor=(0.11, 0.88, 0.8, 0), loc="lower left", mode="expand", ncol=4, fontsize=20)

#plt.savefig('figs/pk_all_wpol_hifreq', dpi=300, bbox_inches="tight")
